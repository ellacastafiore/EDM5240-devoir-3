# %% [markdown]
# # Ce travail risque encore de me donner des sueurs froides!

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
pd.set_option("display.float_format", lambda x : "%.2f" % x)

# %%
ati = pd.read_csv("ati.csv")

# %%
ati
# Out:
#        year  month request_number  \
# 0      2016      3   A-2015-00070
# 1      2015      4   A-2015-00001
# 2      2015      4   A-2014-00219
# 3      2015      4   A-2014-00218
# 4      2015      4   A-2014-00217
# 5      2015      4   A-2014-00216
# 6      2015      4   A-2014-00214
# 7      2015      4   A-2014-00210
# 8      2015      4   A-2014-00213
# 9      2015      6   A-2015-00012
# 10     2015      4   A-2014-00212
# 11     2015      4   A-2014-00200
# 12     2015      4   A-2014-00140
# 13     2015      5   A-2015-00003
# 14     2015      4   A-2014-00112
# 15     2015      5   A-2014-00211
# 16     2015      4   A-2014-00098
# 17     2015      4   A-2014-00070
# 18     2015      4   A-2015-00009
# 19     2015      5   A-2015-00011
# 20     2015      5   A-2015-00010
# 21     2015      5   A-2015-00006
# 22     2015      5   A-2014-00209
# 23     2015      5   A-2014-00145
# 24     2015      5   A-2014-00137
# 25     2015      5   A-2014-00134
# ...

# %% [markdown]
# Ceci est pour savoir la longueur de mon fichier

# %%
ati.shape
# Out:
# (28761, 9)

# %% [markdown]
# Ceci est pour savoir les libellés des colonnes où chercher de l'information

# %%
ati.columns
# Out:
# Index(['year', 'month', 'request_number', 'summary_en', 'summary_fr',
#        'disposition', 'pages', 'owner_org', 'owner_org_title'],
#       dtype='object')

# %% [markdown]
# Pour savoir un peu le type de données qui se trouvent à l'intérieur du fichier

# %%
ati.dtypes
# Out:
# year                int64
# month               int64
# request_number     object
# summary_en         object
# summary_fr         object
# disposition        object
# pages               int64
# owner_org          object
# owner_org_title    object
# dtype: object

# %% [markdown]
# On se rend compte que, sur les 28761 articles du fichier, certaines données sont manquantes (exemple: request_numbers), et qu'il y a plus de sommaires en anglais qu'en français (ah, le bilinguisme!)

# %%
ati.count()
# Out:
# year               28761
# month              28761
# request_number     28748
# summary_en         28741
# summary_fr         28667
# disposition        28740
# pages              28761
# owner_org          28761
# owner_org_title    28761
# dtype: int64

# %% [markdown]
# Pour savoir les données s'étendent entre quelles années

# %%
ati.year.min()
# Out:
# 2015

# %%
ati.year.max()
# Out:
# 2017

# %% [markdown]
# Pour savoir si les données qu'on a sont partielles ou s'il y en de de cachées (ah, le gouvernement!)

# %%
ati.disposition
# Out:
# 0        Disclosed in part / Communication partielle
# 1         No records exist / Aucun document existant
# 2         No records exist / Aucun document existant
# 3            Disclosed in part / Divulgués en partie
# 4         No records exist / Aucun document existant
# 5            Disclosed in part / Divulgués en partie
# 6            Disclosed in part / Divulgués en partie
# 7                         All excluded / Tous exclus
# 8            Disclosed in part / Divulgués en partie
# 9        Disclosed in part / Communication partielle
# 10           Disclosed in part / Divulgués en partie
# 11           Disclosed in part / Divulgués en partie
# 12           Disclosed in part / Divulgués en partie
# 13              All disclosed / Communication totale
# 14           Disclosed in part / Divulgués en partie
# 15       Disclosed in part / Communication partielle
# 16           Disclosed in part / Divulgués en partie
# 17           Disclosed in part / Divulgués en partie
# ...

# %% [markdown]
# Pour savoir qui sont les ministère les plus fréquemment interrogés.

# %%
ati.owner_org.value_counts()
# Out:
# dnd-mdn         2605
# dfatd-maecd     1650
# esdc-edsc       1541
# cic             1323
# hc-sc           1164
# rcmp-grc        1121
# pwgsc-tpsgc     1116
# cra-arc         1046
# tc              1026
# fin             1011
# pco-bcp          997
# aandc-aadnc      911
# lac-bac          897
# ic               893
# cbsa-asfc        872
# nrcan-rncan      783
# jus              737
# dfo-mpo          713
# pch              637
# ps-sp            627
# ec               616
# tbs-sct          578
# cfia-acia        498
# csc-scc          420
# vac-acc          372
# ssc-spc          346
# csis-scrs        335
# infc             283
# cnsc-ccsn        254
# aafc-aac         245
#                 ...
# wd-deo            14
# jccbi-pjcci       12
# ocl-cal           12
# pmprb-cepmb       11
# cannor            11
# vrab-tacra        10
# bdc                9
# pspib-oirpsp       8
# fcac-acfc          7
# cpc-cpp            7
# petf-fpet          7
# wdba-apwd          7
# ...

# %% [markdown]
# Pour un peu voir le taux d'information divulguée en totalement, en partie ou pas du tout à la suite des demandes d'accès à l'information.

# %%
ati.disposition.value_counts()
# Out:
# Disclosed in part / Communication partielle                                                                                                                                                                                                                                                                                                    8653
# All disclosed / Communication totale                                                                                                                                                                                                                                                                                                           2907
# ...

# %% [markdown]
# Pour savoir le pourcentage de données divulguées, tous les organismes confondus

# %%
ati.disposition.value_counts() / len(ati.disposition)*100
# Out:
# Disclosed in part / Communication partielle                                                                                                                                                                                                                                                                                                   30.09
# All disclosed / Communication totale                                                                                                                                                                                                                                                                                                          10.11
# ...
